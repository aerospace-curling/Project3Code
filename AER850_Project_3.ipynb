# %% [markdown]
# <a href="https://colab.research.google.com/github/aerospace-curling/Project3Code/blob/main/AER850_Project_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !uv pip install ultralytics
# Out:
# Using Python 3.12.12 environment at: /usr
# Audited 1 package in 94ms

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

#MODEL 1- SAVED AS pcb_model
#importing YOLO from ultralytics
from ultralytics import YOLO
#importing the pretrained YOLO v11 Model
model = YOLO('yolo11n.pt')
#training the model, 16 is the default batch size and will be used in this analysis. The number of epochs was selected to be 80 to start with, and the image size was set to 900
#the files were saved in my Google Drive in a folder called yolo_results
#results=model.train(data="/content/drive/MyDrive/data/data.yaml",epochs=80,batch=16,imgsz=900,name='pcb_model_1',project="/content/drive/MyDrive/yolo_results")

#MODEL 2- SAVED AS pcb_model-2
#training the model, 16 is the default batch size and will be used in this analysis. The number of epochs was selected to be 200, and the image size was set to 900
#the files were saved in my Google Drive in a folder called yolo_results
#results2=model.train(data="/content/drive/MyDrive/data/data.yaml",epochs=200,batch=16,imgsz=900,name='pcb_model_2', project="/content/drive/MyDrive/yolo_results")

#MODEL 2 was tested being that it was above the highest allowable number of epochs to see what the high end would look like (but must be omitted), now MODEL 3 will be tested
#MODEL 3- SAVED AS pcb-model3
#MODEL 2- SAVED AS pcb_model-1
#training the model, 16 is the default batch size and will be used in this analysis. The number of epochs was selected to be 195, and the image size was set to 900
#the files were saved in my Google Drive in a folder called yolo_results
results3=model.train(data="/content/drive/MyDrive/data/data.yaml",epochs=195,batch=16,imgsz=900,name='pcb_model_3', project="/content/drive/MyDrive/yolo_results")
# Out:
# Mounted at /content/drive
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
#STEP 3: MODEL EVALUATION
#importing YOLO
from ultralytics import YOLO
#importing the third model as previously trained and stored in the Google Drive
model3 = YOLO("/content/drive/MyDrive/yolo_results/pcb_model_3/weights/best.pt")

#using the trained model to predict the three images in the evaluation folder
model3.predict("/content/drive/MyDrive/data/evaluation/ardmega.jpg", save=True)
model3.predict("/content/drive/MyDrive/data/evaluation/arduno.jpg", save=True)
model3.predict("/content/drive/MyDrive/data/evaluation/rasppi.jpg", save=True)
# Out:
# image 1/1 /content/drive/MyDrive/data/evaluation/ardmega.jpg: 832x928 1 Button, 13 Capacitors, 10 Connectors, 7 ICs, 21 Resistors, 82.3ms
# Speed: 6.8ms preprocess, 82.3ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 928)
# Results saved to /content/runs/detect/predict
#
# image 1/1 /content/drive/MyDrive/data/evaluation/arduno.jpg: 640x928 1 Button, 11 Capacitors, 12 Connectors, 3 Electrolytic Capacitors, 6 ICs, 1 Led, 1 Pads, 7 Resistors, 81.7ms
# Speed: 4.7ms preprocess, 81.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 928)
# Results saved to /content/runs/detect/predict
#
# image 1/1 /content/drive/MyDrive/data/evaluation/rasppi.jpg: 640x928 11 Capacitors, 10 Connectors, 1 Electrolytic Capacitor, 13 ICs, 3 Inductors, 4 Leds, 26 Resistors, 1 Switch, 9.9ms
# Speed: 4.5ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 928)
# Results saved to /content/runs/detect/predict
# ...
